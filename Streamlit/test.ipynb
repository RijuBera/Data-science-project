# %%
import pandas as pd


startup=pd.read_csv('startup_cleaned.csv')
startup.head(2)
# Out:
#          date startup        vertical                subvertical       city  \
# 0  2020-09-01  BYJU’S          E-Tech                 E-learning  Bengaluru
# 1  2020-01-13  Shuttl  Transportation  App based shuttle service    Gurgaon
#
#                    investors                 round      amount
# 0    Tiger Global Management  Private Equity Round  1650.00000
# 1  Susquehanna Growth Equity              Series C    66.39925

# %%
startup[startup['investors'].str.contains('Tiger Global Management')]
# Out:
#             date                startup  \
# 0     2020-09-01                 BYJU’S
# 52    2019-08-22              INDwealth
# 65    2019-11-07                 Moglix
# 79    2019-10-06               OkCredit
# 87    2019-02-05                 Zenoti
# 101   2019-11-04              CleverTap
# 321   2018-03-22              Chargebee
# 525   2017-10-13                Chaayos
# 2006  2016-12-01              Shopclues
# 2109  2015-10-12              BlackBuck
# 2280  2015-08-10                 Cube26
# 2329  2015-10-26               Razorpay
# 2448  2015-05-08               Zo Rooms
# 2473  2015-10-08            Grey Orange
# 2557  2015-08-07                  Saavn
# 2565  2015-08-07                Lybrate
# 2606  2015-07-29  Zovi.com / Little App
# 2713  2015-06-05              Delhivery
# 2718  2015-07-05                Vedantu
# 2736  2015-05-19                Chaayos
# 2783  2015-04-14               LocalOye
#
#                                       vertical  \
# ...
